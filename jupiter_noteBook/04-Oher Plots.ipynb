# %% [markdown]
# # line Plot with multifacets

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

nuqta = sns.load_dataset("dots")
nuqta.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
nuqta = sns.load_dataset("dots")

# Defining a color palette
palette = sns.color_palette("rocket_r")

# Plot lineplot
sns.relplot(
    data=nuqta,
    x="time",
    y="firing_rate",
    hue="coherence",
    size="choice",
    col="align",
    kind="line",
    size_order=["T1", "T2"],
    palette=palette,
    height=5,
    aspect=0.75,
    facet_kws=dict(sharex=False)
)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested boxplot to show bill by day and time
sns.boxplot(x="day", y="total_bill",
            hue="smoker", palette=["m", "g"],
            data=tips)
sns.despine(offset=10, trim=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested boxplot to show bill by day and time
sns.violinplot(data= tips, x="day", y="total_bill", hue="smoker",
               split=True, inner="quart", linewidth=1,
               palette={"Yes": "b", "No": ".85",})
sns.despine(offset=10, trim=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# Load the example diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Draw a scatter plot while assigning point colors and size to different variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)

# Define the clarity ranking for ordering
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

# Create scatter plot
sns.scatterplot(
    x="carat", y="price",
    hue="clarity", size="depth",
    palette="ch:r=-.2,d=.3_r",
    hue_order=clarity_ranking,
    sizes=(20, 200), linewidth=0,
    data=diamonds, ax=ax
)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# Load the example planets dataset
planets = sns.load_dataset("planets")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="distance", y="method", data=planets,
            whis=(0, 100), width=.6, palette="vlag")

# Add points to show each observation
sns.stripplot(x="distance", y="method", data=planets,
              size=4, color=".3", linewidth=0)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set_ylabel("")  # Removing the y-axis label
sns.despine(trim=True, left=True)

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1864\2613173522.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="distance", y="method", data=planets,

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the brain networks dataset, select subset, and collapse the multi-index
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

used_networks = [1, 5, 6, 7, 8, 12, 13, 17]
used_columns = (df.columns
                  .get_level_values("network")
                  .astype(int)
                  .isin(used_networks))
df = df.loc[:, used_columns]

df.columns = df.columns.map("-".join)

# Compute a correlation matrix and convert to long-form
corr_mat = df.corr().stack().reset_index(name="correlation")

# Draw each cell as a scatter point with varying size and color
g = sns.relplot(
    data=corr_mat,
    x="level_0", y="level_1", hue="correlation", size="correlation",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),
)

# Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)
g.ax.margins(.02)
for label in g.ax.get_xticklabels():
    label.set_rotation(90)

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

nuqta = sns.load_dataset("dots")
nuqta.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
diamond = sns.load_dataset("diamonds")
diamond.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

nuqta = sns.load_dataset("dots")
# clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(x="choice", y="coherence",
              color="blue",
              scale="lines", data=nuqta)
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1864\3738027400.py:7: FutureWarning:
#
# The `scale` parameter has been renamed to `width_method` and will be removed in v0.15. Pass `width_method='lines' for the same effect.
#   sns.boxenplot(x="choice", y="coherence",
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 7
#       4 nuqta = sns.load_dataset("dots")
#       5 # clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
# ----> 7 sns.boxenplot(x="choice", y="coherence",
#       8               color="blue",
#       9               scale="lines", data=nuqta)
#      10 plt.show()
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# Load the example "dots" dataset
nuqta = sns.load_dataset("dots")

# Create a boxenplot with a blue color
sns.boxenplot(x="choice", y="coherence", 
              color="blue", scale="lines", data=nuqta)

# Show the plot
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1864\564740920.py:10: FutureWarning:
#
# The `scale` parameter has been renamed to `width_method` and will be removed in v0.15. Pass `width_method='lines' for the same effect.
#   sns.boxenplot(x="choice", y="coherence",
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 10
#       7 nuqta = sns.load_dataset("dots")
#       9 # Create a boxenplot with a blue color
# ---> 10 sns.boxenplot(x="choice", y="coherence",
#      11               color="blue", scale="lines", data=nuqta)
#      13 # Show the plot
#      14 plt.show()
#
# ...

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# Load the example "dots" dataset
nuqta = sns.load_dataset("dots")

# Check if the dataset loaded correctly
print(nuqta.head())

# Create a boxenplot with a blue color
sns.boxenplot(x="choice", y="coherence", 
              color="blue", scale="lines", data=nuqta)

# Show the plot
plt.show()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_28152\556829325.py:14: FutureWarning:
#
# The `scale` parameter has been renamed to `width_method` and will be removed in v0.15. Pass `width_method='lines' for the same effect.
#   sns.boxenplot(x="choice", y="coherence",
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 14
#      11 print(nuqta.head())
#      13 # Create a boxenplot with a blue color
# ---> 14 sns.boxenplot(x="choice", y="coherence",
#      15               color="blue", scale="lines", data=nuqta)
#      17 # Show the plot
#      18 plt.show()
#
# ...
